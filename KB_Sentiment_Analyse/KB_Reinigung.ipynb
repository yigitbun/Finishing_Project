# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("klinikbew.csv")

# %%
df.describe().transpose()
# Out:
#                     count unique  \
# NameKlinik           3354     24
# Titel                3352   3095
# DatumBewertung       3354   2339
# Fachbereich          3350     35
# Erfahrungsbericht    3310   3309
# Gesamtzufriedenheit  3354      4
# QualitätBeratung     3354      4
# MedizBehandlung      3354      4
# VerwaltungAblaeufe   3354      4
#
#                                                                    top  freq
# NameKlinik           Diana Klinik-Fachklinik für Physikalische Medizin   330
# Titel                                                   Sehr zufrieden    19
# DatumBewertung                                              07.03.2019     6
# Fachbereich                                                 Orthopädie   376
# Erfahrungsbericht    Die An- und Abreise im Januar 2013 waren perfe...     2
# Gesamtzufriedenheit                                             star-6  1654
# QualitätBeratung                                                star-6  1633
# MedizBehandlung                                                 star-6  1786
# VerwaltungAblaeufe                                              star-6  1257

# %% [markdown]
# ### Missing Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3354 entries, 0 to 3353
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   NameKlinik           3354 non-null   object
#  1   Titel                3352 non-null   object
#  2   DatumBewertung       3354 non-null   object
#  3   Fachbereich          3350 non-null   object
#  4   Erfahrungsbericht    3310 non-null   object
#  5   Gesamtzufriedenheit  3354 non-null   object
#  6   QualitätBeratung     3354 non-null   object
#  7   MedizBehandlung      3354 non-null   object
#  8   VerwaltungAblaeufe   3354 non-null   object
# dtypes: object(9)
# memory usage: 236.0+ KB

# %%
count = df.isnull().sum().sort_values(ascending=False)
percentage = ((df.isnull().sum()/len(df)*100)).sort_values(ascending=False)
missing_data = pd.concat([count, percentage], axis=1, keys=['Count','Percentage'])

print('Percentage of missing values of the columns:')

missing_data
# Out:
# Percentage of missing values of the columns:
#                      Count  Percentage
# Erfahrungsbericht       44    1.311866
# Fachbereich              4    0.119261
# Titel                    2    0.059630
# NameKlinik               0    0.000000
# DatumBewertung           0    0.000000
# Gesamtzufriedenheit      0    0.000000
# QualitätBeratung         0    0.000000
# MedizBehandlung          0    0.000000
# VerwaltungAblaeufe       0    0.000000

# %% [markdown]
# Dropping the missing values

# %%
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3304 entries, 0 to 3353
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   NameKlinik           3304 non-null   object
#  1   Titel                3304 non-null   object
#  2   DatumBewertung       3304 non-null   object
#  3   Fachbereich          3304 non-null   object
#  4   Erfahrungsbericht    3304 non-null   object
#  5   Gesamtzufriedenheit  3304 non-null   object
#  6   QualitätBeratung     3304 non-null   object
#  7   MedizBehandlung      3304 non-null   object
#  8   VerwaltungAblaeufe   3304 non-null   object
# dtypes: object(9)
# memory usage: 258.1+ KB

# %% [markdown]
# ### Befreien von Zeilen

# %%
df = df.replace('\n',' ', regex=True)

# %%
df.head()
# Out:
#                         NameKlinik                       Titel DatumBewertung  \
# 0  HEH Herzogin Elisabeth Hospital                   Bewertung     09.06.2021
# 1  HEH Herzogin Elisabeth Hospital               Weiter so HEH     09.06.2021
# 2  HEH Herzogin Elisabeth Hospital                 Superklinik     07.06.2021
# 3  HEH Herzogin Elisabeth Hospital  Kranken- oder Hotelzimmer?     25.05.2021
# 4  HEH Herzogin Elisabeth Hospital                     Knie OP     11.05.2021
#
#        Fachbereich                                  Erfahrungsbericht  \
# 0        Chirurgie  Sehr höfliche und hilfsbereite Mitarbeiter.  S...
# 1        Chirurgie  Kann ich nur weiterempfehlen!! Sehr gutes Pfle...
# 2       Orthopädie  Bestens durchorganisiert.gutes Personal geht i...
# 3  Unfallchirurgie  Bin nach einem Autounfall im HEH gewesen und h...
# 4       Orthopädie  Wurde bereits im Sept. 2020 am Knie operiert. ...
#
#   Gesamtzufriedenheit QualitätBeratung MedizBehandlung VerwaltungAblaeufe
# 0              star-6           star-6          star-6             star-6
# 1              star-6           star-4          star-6             star-4
# 2              star-6           star-6          star-6             star-6
# 3              star-6           star-6          star-6             star-6
# 4              star-6           star-6          star-6             star-6

# %% [markdown]
# ### Sterne
# Sterne sind Texte, sollten in Zahlen geändert werden

# %%
# Düzenle
# np.vectorize(cleanup)(df['Gesamtzufriedenheit'])
# def cleanup(name):
  #  name = name.str.split('-').str[1]
   # return name

# %%
df['Gesamt'] = df['Gesamtzufriedenheit'].str.split('-').str[1]
df['QualBeratung'] = df['QualitätBeratung'].str.split('-').str[1]
df['MedBehandlung'] = df['MedizBehandlung'].str.split('-').str[1]
df['VerwalAblaeufe'] = df['VerwaltungAblaeufe'].str.split('-').str[1]

# %%
df[['NameKlinik', 'Erfahrungsbericht', 'Gesamt']]
# Out:
#                                              NameKlinik  \
# 0                       HEH Herzogin Elisabeth Hospital
# 1                       HEH Herzogin Elisabeth Hospital
# 2                       HEH Herzogin Elisabeth Hospital
# 3                       HEH Herzogin Elisabeth Hospital
# 4                       HEH Herzogin Elisabeth Hospital
# ...                                                 ...
# 3349  Diana Klinik-Fachklinik für Physikalische Medizin
# 3350  Diana Klinik-Fachklinik für Physikalische Medizin
# 3351  Diana Klinik-Fachklinik für Physikalische Medizin
# 3352  Diana Klinik-Fachklinik für Physikalische Medizin
# 3353  Diana Klinik-Fachklinik für Physikalische Medizin
#
#                                       Erfahrungsbericht Gesamt
# 0     Sehr höfliche und hilfsbereite Mitarbeiter.  S...      6
# 1     Kann ich nur weiterempfehlen!! Sehr gutes Pfle...      6
# 2     Bestens durchorganisiert.gutes Personal geht i...      6
# 3     Bin nach einem Autounfall im HEH gewesen und h...      6
# 4     Wurde bereits im Sept. 2020 am Knie operiert. ...      6
# ...                                                 ...    ...
# 3349  Schematisches Konzept. Man sollte sagen, was m...      6
# 3350  Ich war von Maerz 2008 bis Ende April als Pati...      6
# 3351  Ich hatte dort einen 7-wöchigen Aufenthalt in ...      0
# 3352  Erstmal ist es sehr wichtig zu wissen, dass de...      0
# 3353  Ich war 2006 für 6 Wochen Patientin in der Dia...      4
#
# [3304 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3304 entries, 0 to 3353
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   NameKlinik           3304 non-null   object
#  1   Titel                3304 non-null   object
#  2   DatumBewertung       3304 non-null   object
#  3   Fachbereich          3304 non-null   object
#  4   Erfahrungsbericht    3304 non-null   object
#  5   Gesamtzufriedenheit  3304 non-null   object
#  6   QualitätBeratung     3304 non-null   object
#  7   MedizBehandlung      3304 non-null   object
#  8   VerwaltungAblaeufe   3304 non-null   object
#  9   Gesamt               3304 non-null   object
#  10  QualBeratung         3304 non-null   object
#  11  MedBehandlung        3304 non-null   object
#  12  VerwalAblaeufe       3304 non-null   object
# dtypes: object(13)
# memory usage: 361.4+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3304 entries, 0 to 3353
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   NameKlinik           3304 non-null   object
#  1   Titel                3304 non-null   object
#  2   DatumBewertung       3304 non-null   object
#  3   Fachbereich          3304 non-null   object
#  4   Erfahrungsbericht    3304 non-null   object
#  5   Gesamtzufriedenheit  3304 non-null   object
#  6   QualitätBeratung     3304 non-null   object
#  7   MedizBehandlung      3304 non-null   object
#  8   VerwaltungAblaeufe   3304 non-null   object
#  9   Gesamt               3304 non-null   object
#  10  QualBeratung         3304 non-null   object
#  11  MedBehandlung        3304 non-null   object
#  12  VerwalAblaeufe       3304 non-null   object
# dtypes: object(13)
# memory usage: 361.4+ KB

# %%
df = df.dropna()

# %%
df
# Out:
#                                              NameKlinik  \
# 0                       HEH Herzogin Elisabeth Hospital
# 1                       HEH Herzogin Elisabeth Hospital
# 2                       HEH Herzogin Elisabeth Hospital
# 3                       HEH Herzogin Elisabeth Hospital
# 4                       HEH Herzogin Elisabeth Hospital
# ...                                                 ...
# 3349  Diana Klinik-Fachklinik für Physikalische Medizin
# 3350  Diana Klinik-Fachklinik für Physikalische Medizin
# 3351  Diana Klinik-Fachklinik für Physikalische Medizin
# 3352  Diana Klinik-Fachklinik für Physikalische Medizin
# 3353  Diana Klinik-Fachklinik für Physikalische Medizin
#
#                                                   Titel DatumBewertung  \
# 0                                             Bewertung     09.06.2021
# 1                                         Weiter so HEH     09.06.2021
# 2                                           Superklinik     07.06.2021
# 3                            Kranken- oder Hotelzimmer?     25.05.2021
# 4                                               Knie OP     11.05.2021
# ...                                                 ...            ...
# 3349  Gute Therapie und Konzept Diese Bewertung geht...     19.11.2008
# 3350  Erinnerung an Diana Klinik 2 Diese Bewertung g...     12.11.2008
# 3351  Schöner Kurort - schlechte psychosomatische Kl...     13.10.2008
# 3352  Ruhe und Erholung - aber keine Therapie! Diese...     07.10.2008
# 3353  Ein Super Erholungsort, aber keine Klinik für ...     03.02.2008
#
#           Fachbereich                                  Erfahrungsbericht  \
# 0           Chirurgie  Sehr höfliche und hilfsbereite Mitarbeiter.  S...
# 1           Chirurgie  Kann ich nur weiterempfehlen!! Sehr gutes Pfle...
# 2          Orthopädie  Bestens durchorganisiert.gutes Personal geht i...
# 3     Unfallchirurgie  Bin nach einem Autounfall im HEH gewesen und h...
# 4          Orthopädie  Wurde bereits im Sept. 2020 am Knie operiert. ...
# ...               ...                                                ...
# 3349       Orthopädie  Schematisches Konzept. Man sollte sagen, was m...
# 3350    Psychosomatik  Ich war von Maerz 2008 bis Ende April als Pati...
# 3351    Psychosomatik  Ich hatte dort einen 7-wöchigen Aufenthalt in ...
# 3352    Psychosomatik  Erstmal ist es sehr wichtig zu wissen, dass de...
# 3353    Psychosomatik  Ich war 2006 für 6 Wochen Patientin in der Dia...
#
#      Gesamtzufriedenheit QualitätBeratung MedizBehandlung VerwaltungAblaeufe  \
# 0                 star-6           star-6          star-6             star-6
# 1                 star-6           star-4          star-6             star-4
# 2                 star-6           star-6          star-6             star-6
# 3                 star-6           star-6          star-6             star-6
# 4                 star-6           star-6          star-6             star-6
# ...                  ...              ...             ...                ...
# 3349              star-6           star-4          star-6             star-4
# 3350              star-6           star-6          star-0             star-4
# 3351              star-0           star-2          star-0             star-0
# 3352              star-0           star-0          star-4             star-4
# 3353              star-4           star-2          star-2             star-4
#
#      Gesamt QualBeratung MedBehandlung VerwalAblaeufe
# 0         6            6             6              6
# 1         6            4             6              4
# 2         6            6             6              6
# 3         6            6             6              6
# 4         6            6             6              6
# ...     ...          ...           ...            ...
# 3349      6            4             6              4
# 3350      6            6             0              4
# 3351      0            2             0              0
# 3352      0            0             4              4
# 3353      4            2             2              4
#
# [3304 rows x 13 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3304 entries, 0 to 3353
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   NameKlinik           3304 non-null   object
#  1   Titel                3304 non-null   object
#  2   DatumBewertung       3304 non-null   object
#  3   Fachbereich          3304 non-null   object
#  4   Erfahrungsbericht    3304 non-null   object
#  5   Gesamtzufriedenheit  3304 non-null   object
#  6   QualitätBeratung     3304 non-null   object
#  7   MedizBehandlung      3304 non-null   object
#  8   VerwaltungAblaeufe   3304 non-null   object
#  9   Gesamt               3304 non-null   object
#  10  QualBeratung         3304 non-null   object
#  11  MedBehandlung        3304 non-null   object
#  12  VerwalAblaeufe       3304 non-null   object
# dtypes: object(13)
# memory usage: 361.4+ KB
