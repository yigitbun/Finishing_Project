# %%
# conda install -c https://conda.anaconda.org/conda-forge wordcloud

# %%
import numpy as np
import pandas as pd
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

import matplotlib.pyplot as plt

# %%
df = pd.read_csv("kbClean.csv")

# %%
df.head()
# Out:
#                     NameKlinik  \
# 0  Herzogin Elisabeth Hospital
# 1  Herzogin Elisabeth Hospital
# 2  Herzogin Elisabeth Hospital
# 3  Herzogin Elisabeth Hospital
# 4  Herzogin Elisabeth Hospital
#
#                                    Erfahrungsbericht  Gesamt  QualBeratung  \
# 0  Sehr höfliche und hilfsbereite Mitarbeiter.  S...     5.0           5.0
# 1  Kann ich nur weiterempfehlen!! Sehr gutes Pfle...     5.0           3.7
# 2  Bestens durchorganisiert.gutes Personal geht i...     5.0           5.0
# 3  Bin nach einem Autounfall im HEH gewesen und h...     5.0           5.0
# 4  Wurde bereits im Sept. 2020 am Knie operiert. ...     5.0           5.0
#
#    MedBehandlung  VerwalAblaeufe Zufriedenheit  ist_zufrieden  Polarity Level  \
# 0            5.0             5.0       Positiv              1        0.462500
# 1            5.0             3.7       Positiv              1        0.000000
# 2            5.0             5.0       Positiv              1        0.000000
# ...

# %%
yeni_df = df[df['NameKlinik'] == 'HEH Herzogin Elisabeth Hospital']

# %%
text = ""
for i in yeni_df['Erfahrungsbericht']:
    text += i

# %%
len(text)
# Out:
# 0

# %%
# Start with one review:
text = df.Erfahrungsbericht[0]

# Create and generate a word cloud image:
wordcloud = WordCloud(background_color="#fbf5e5").generate(text)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
plt.savefig('plot2.png')
